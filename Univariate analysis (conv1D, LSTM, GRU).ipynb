# %% [markdown]
# # I am using the temperature column to predict future temperatures

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 5        94.40          3.33          3.14          0.19       1.96
# 11       93.20          3.12          2.90          0.21       1.81
# 17       93.50          3.13          2.93          0.20       1.83
# 23       92.60          3.07          2.85          0.23       1.78
# 29       92.20          2.94          2.71          0.23       1.69
# ...        ...           ...           ...           ...        ...
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5                  3.15       1307.86      0.21           0.63     192.7
# 11                 2.91       1312.25      0.25           0.63     190.3
# 17                 2.94       1312.18      0.18           0.63     167.2
# 23                 2.85       1313.61      0.10           0.38     240.0
# 29                 2.71       1317.19      0.40           0.88     157.0
# ...                 ...           ...       ...            ...       ...
# 420521             4.08       1280.70      0.87           1.36     190.6
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420533             3.63       1288.02      0.71           1.56     158.7
# 420539             3.57       1288.03      0.35           0.68     216.7
# 420545             3.31       1292.41      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# 2009-01-01 13:00:00  01.01.2009 13:00:00   1000.03     -5.89    267.27
# 2009-01-01 14:00:00  01.01.2009 14:00:00    999.81     -5.94    267.24
# 2009-01-01 15:00:00  01.01.2009 15:00:00    999.88     -5.69    267.48
# 2009-01-01 16:00:00  01.01.2009 16:00:00    999.94     -5.40    267.76
# 2009-01-01 17:00:00  01.01.2009 17:00:00   1000.17     -5.37    267.78
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16     -5.25    267.90
# 2009-01-01 19:00:00  01.01.2009 19:00:00   1000.22     -5.11    268.03
# 2009-01-01 20:00:00  01.01.2009 20:00:00   1000.22     -4.90    268.24
# 2009-01-01 21:00:00  01.01.2009 21:00:00   1000.19     -4.80    268.35
# 2009-01-01 22:00:00  01.01.2009 22:00:00   1000.00     -4.50    268.66
# 2009-01-01 23:00:00  01.01.2009 23:00:00    999.77     -4.47    268.71
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59     -4.54    268.65
# 2009-01-02 01:00:00  02.01.2009 01:00:00    999.34     -4.44    268.77
# 2009-01-02 02:00:00  02.01.2009 02:00:00    998.93     -4.29    268.95
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2009-01-01 01:00:00        -8.78    94.4          3.33          3.14
# 2009-01-01 02:00:00        -9.77    93.2          3.12          2.90
# 2009-01-01 03:00:00        -9.66    93.5          3.13          2.93
# 2009-01-01 04:00:00       -10.02    92.6          3.07          2.85
# 2009-01-01 05:00:00       -10.65    92.2          2.94          2.71
# 2009-01-01 06:00:00       -10.62    92.7          2.93          2.71
# 2009-01-01 07:00:00       -10.10    92.9          3.04          2.83
# 2009-01-01 08:00:00        -9.05    92.8          3.31          3.07
# 2009-01-01 09:00:00        -8.84    91.2          3.43          3.13
# 2009-01-01 10:00:00        -8.17    91.6          3.60          3.30
# 2009-01-01 11:00:00        -8.66    90.7          3.50          3.17
# 2009-01-01 12:00:00        -8.28    89.6          3.64          3.27
# 2009-01-01 13:00:00        -7.46    88.6          3.93          3.48
# 2009-01-01 14:00:00        -7.43    89.1          3.92          3.49
# 2009-01-01 15:00:00        -7.00    90.4          3.99          3.61
# 2009-01-01 16:00:00        -6.86    89.4          4.08          3.65
# 2009-01-01 17:00:00        -6.82    89.4          4.09          3.66
# 2009-01-01 18:00:00        -6.75    89.1          4.13          3.68
# 2009-01-01 19:00:00        -6.57    89.4          4.17          3.73
# 2009-01-01 20:00:00        -6.38    89.3          4.24          3.79
# 2009-01-01 21:00:00        -6.14    90.2          4.27          3.85
# 2009-01-01 22:00:00        -5.82    90.4          4.37          3.95
# 2009-01-01 23:00:00        -5.84    90.1          4.38          3.95
# 2009-01-02 00:00:00        -5.46    93.2          4.36          4.06
# 2009-01-02 01:00:00        -5.19    94.4          4.39          4.15
# 2009-01-02 02:00:00        -5.04    94.5          4.44          4.20
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2009-01-01 01:00:00          0.19       1.96             3.15       1307.86
# 2009-01-01 02:00:00          0.21       1.81             2.91       1312.25
# 2009-01-01 03:00:00          0.20       1.83             2.94       1312.18
# 2009-01-01 04:00:00          0.23       1.78             2.85       1313.61
# 2009-01-01 05:00:00          0.23       1.69             2.71       1317.19
# 2009-01-01 06:00:00          0.21       1.69             2.72       1317.71
# 2009-01-01 07:00:00          0.22       1.76             2.83       1315.98
# 2009-01-01 08:00:00          0.24       1.92             3.08       1311.65
# 2009-01-01 09:00:00          0.30       1.95             3.13       1310.14
# 2009-01-01 10:00:00          0.30       2.05             3.29       1307.76
# 2009-01-01 11:00:00          0.33       1.97             3.17       1310.43
# 2009-01-01 12:00:00          0.38       2.03             3.26       1306.98
# 2009-01-01 13:00:00          0.45       2.17             3.48       1301.73
# 2009-01-01 14:00:00          0.43       2.17             3.49       1301.67
# 2009-01-01 15:00:00          0.38       2.25             3.61       1300.51
# 2009-01-01 16:00:00          0.43       2.27             3.65       1299.17
# 2009-01-01 17:00:00          0.43       2.28             3.66       1299.27
# 2009-01-01 18:00:00          0.45       2.29             3.68       1298.68
# 2009-01-01 19:00:00          0.44       2.32             3.73       1298.07
# 2009-01-01 20:00:00          0.45       2.36             3.78       1297.05
# 2009-01-01 21:00:00          0.42       2.40             3.85       1296.45
# 2009-01-01 22:00:00          0.42       2.46             3.95       1294.72
# 2009-01-01 23:00:00          0.43       2.46             3.95       1294.29
# 2009-01-02 00:00:00          0.30       2.53             4.06       1294.33
# 2009-01-02 01:00:00          0.25       2.58             4.15       1293.47
# 2009-01-02 02:00:00          0.24       2.62             4.20       1292.22
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 01:00:00      0.21           0.63     192.7
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 05:00:00      0.40           0.88     157.0
# 2009-01-01 06:00:00      0.05           0.50     146.0
# 2009-01-01 07:00:00      2.08           2.88     348.8
# 2009-01-01 08:00:00      0.72           1.25     213.9
# 2009-01-01 09:00:00      0.34           0.63     202.2
# 2009-01-01 10:00:00      1.45           3.00     292.6
# 2009-01-01 11:00:00      1.91           3.38     269.6
# 2009-01-01 12:00:00      1.84           2.63     184.4
# 2009-01-01 13:00:00      0.57           1.25     187.3
# 2009-01-01 14:00:00      1.25           2.00     144.0
# 2009-01-01 15:00:00      1.17           1.88     134.9
# 2009-01-01 16:00:00      1.40           2.13     145.5
# 2009-01-01 17:00:00      0.85           1.63     142.2
# 2009-01-01 18:00:00      0.55           1.00     183.7
# 2009-01-01 19:00:00      0.41           0.75     176.7
# 2009-01-01 20:00:00      0.68           1.13     195.2
# 2009-01-01 21:00:00      0.44           0.75     206.3
# 2009-01-01 22:00:00      0.33           0.63     175.7
# 2009-01-01 23:00:00      0.65           1.00     219.3
# 2009-01-02 00:00:00      0.41           0.88     155.0
# 2009-01-02 01:00:00      0.28           1.00     148.1
# 2009-01-02 02:00:00      0.49           0.88     209.8

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <AxesSubplot:xlabel='Date Time'>

# %%
def df_to_X_y(df, window_size=5):
      df_as_np = df.to_numpy()
      X = []
      y = []
      for i in range(len(df_as_np)-window_size):
        row = [[a] for a in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size]
        y.append(label)
      return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                16896
# _________________________________________________________________
# dense (Dense)                (None, 8)                 520
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp1 = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), 
               optimizer=Adam(learning_rate=0.0001), 
               metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1858/1875 [============================>.] - ETA: 0s - loss: 27.5987 - root_mean_squared_error: 5.2534WARNING:tensorflow:From C:\Users\TT\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\TT\anaconda3\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 10s 5ms/step - loss: 27.3727 - root_mean_squared_error: 5.2319 - val_loss: 1.1495 - val_root_mean_squared_error: 1.0722
# Epoch 2/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 1.7702 - root_mean_squared_error: 1.3305INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.7701 - root_mean_squared_error: 1.3304 - val_loss: 0.6326 - val_root_mean_squared_error: 0.7954
# Epoch 3/10
# 1863/1875 [============================>.] - ETA: 0s - loss: 0.8734 - root_mean_squared_error: 0.9346INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.8736 - root_mean_squared_error: 0.9347 - val_loss: 0.5430 - val_root_mean_squared_error: 0.7369
# Epoch 4/10
# 1875/1875 [==============================] - ETA: 0s - loss: 0.7259 - root_mean_squared_error: 0.8520INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.7259 - root_mean_squared_error: 0.8520 - val_loss: 0.5230 - val_root_mean_squared_error: 0.7232
# Epoch 5/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.6815 - root_mean_squared_error: 0.8255INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6815 - root_mean_squared_error: 0.8255 - val_loss: 0.5052 - val_root_mean_squared_error: 0.7108
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6646 - root_mean_squared_error: 0.8152 - val_loss: 0.5337 - val_root_mean_squared_error: 0.7305
# Epoch 7/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.6550 - root_mean_squared_error: 0.8093INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6561 - root_mean_squared_error: 0.8100 - val_loss: 0.5035 - val_root_mean_squared_error: 0.7096
# Epoch 8/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.6513 - root_mean_squared_error: 0.8071INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6514 - root_mean_squared_error: 0.8071 - val_loss: 0.4964 - val_root_mean_squared_error: 0.7046
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6475 - root_mean_squared_error: 0.8047 - val_loss: 0.4997 - val_root_mean_squared_error: 0.7069
# Epoch 10/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.6443 - root_mean_squared_error: 0.8027 - val_loss: 0.5042 - val_root_mean_squared_error: 0.7100

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
#        Train Predictions  Actuals
# 0              -9.812234    -9.67
# 1              -9.593262    -9.17
# 2              -8.728249    -8.10
# 3              -7.275221    -7.66
# 4              -7.139719    -7.04
# ...                  ...      ...
# 59995           6.013011     6.07
# 59996           7.370484     9.88
# 59997          12.328268    13.53
# 59998          16.229343    15.43
# 59999          16.445686    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100], label="Predictions")
plt.plot(train_results['Actuals'][50:100], label="Actual")
plt.legend(loc="upper left")

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
#       Val Predictions  Actuals
# 0           15.437525    14.02
# 1           13.303396    13.67
# 2           13.149222    12.27
# 3           11.581982    11.19
# 4           10.461733    10.85
# ...               ...      ...
# 4995        17.398863    18.27
# 4996        17.467224    17.85
# 4997        17.273340    16.65
# 4998        15.931578    15.85
# 4999        15.159700    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100], label="Predictions")
plt.plot(val_results['Actuals'][:100], label="Actual")
plt.legend(loc="upper left")

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
#       Test Predictions  Actuals
# 0            14.473423    13.99
# 1            13.325409    13.46
# 2            12.933561    12.93
# 3            12.527542    12.43
# 4            12.087965    12.17
# ...                ...      ...
# 5081         -0.877276    -0.98
# 5082         -1.377677    -1.40
# 5083         -1.638376    -2.75
# 5084         -2.984217    -2.89
# 5085         -3.067730    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100], label="Predictions")
plt.plot(test_results['Actuals'][:100],label="Actual")
plt.title('Actual (blue) vs Predictions (Orange)')
plt.xlabel('time in hours')
plt.legend(loc="upper left")

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end], label="Predictions")
  plt.plot(df['Actuals'][start:end],label="Actual")
  plt.legend(loc="upper left")
  return df, mse(y, predictions)

# %%
plot_predictions1(model1, X_test1, y_test1)
# Out:
# (      Predictions  Actuals
#  0       14.473423    13.99
#  1       13.325409    13.46
#  2       12.933561    12.93
#  3       12.527542    12.43
#  4       12.087965    12.17
#  ...           ...      ...
#  5081    -0.877276    -0.98
#  5082    -1.377677    -1.40
#  5083    -1.638376    -2.75
#  5084    -2.984217    -2.89
#  5085    -3.067730    -3.93
#
#  [5086 rows x 2 columns],
#  0.6173770446998946)

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 4, 64)             192
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 2056
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 2,257
# Trainable params: 2,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp2 = ModelCheckpoint('model2/', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 1812/1875 [===========================>..] - ETA: 0s - loss: 6.2128 - root_mean_squared_error: 2.4926INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 6.0673 - root_mean_squared_error: 2.4632 - val_loss: 1.0650 - val_root_mean_squared_error: 1.0320
# Epoch 2/10
# 1852/1875 [============================>.] - ETA: 0s - loss: 0.9465 - root_mean_squared_error: 0.9729INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.9450 - root_mean_squared_error: 0.9721 - val_loss: 0.6194 - val_root_mean_squared_error: 0.7870
# Epoch 3/10
# 1860/1875 [============================>.] - ETA: 0s - loss: 0.7416 - root_mean_squared_error: 0.8611INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7414 - root_mean_squared_error: 0.8610 - val_loss: 0.5387 - val_root_mean_squared_error: 0.7340
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7129 - root_mean_squared_error: 0.8444 - val_loss: 0.5421 - val_root_mean_squared_error: 0.7363
# Epoch 5/10
# 1831/1875 [============================>.] - ETA: 0s - loss: 0.7014 - root_mean_squared_error: 0.8375INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7005 - root_mean_squared_error: 0.8370 - val_loss: 0.5206 - val_root_mean_squared_error: 0.7215
# Epoch 6/10
# 1855/1875 [============================>.] - ETA: 0s - loss: 0.6987 - root_mean_squared_error: 0.8359INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6980 - root_mean_squared_error: 0.8355 - val_loss: 0.5163 - val_root_mean_squared_error: 0.7185
# Epoch 7/10
# 1875/1875 [==============================] - 2s 855us/step - loss: 0.6964 - root_mean_squared_error: 0.8345 - val_loss: 0.5203 - val_root_mean_squared_error: 0.7214
# Epoch 8/10
# 1875/1875 [==============================] - 2s 870us/step - loss: 0.6953 - root_mean_squared_error: 0.8338 - val_loss: 0.5401 - val_root_mean_squared_error: 0.7349
# Epoch 9/10
# 1813/1875 [============================>.] - ETA: 0s - loss: 0.6945 - root_mean_squared_error: 0.8334INFO:tensorflow:Assets written to: model2\assets
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6951 - root_mean_squared_error: 0.8338 - val_loss: 0.5126 - val_root_mean_squared_error: 0.7160
# Epoch 10/10
# 1875/1875 [==============================] - 2s 888us/step - loss: 0.6928 - root_mean_squared_error: 0.8323 - val_loss: 0.5171 - val_root_mean_squared_error: 0.7191

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 64)                12864
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 13,393
# Trainable params: 13,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp3 = ModelCheckpoint('model3/', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 26.4957 - root_mean_squared_error: 5.1474INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 26.3693 - root_mean_squared_error: 5.1351 - val_loss: 0.9608 - val_root_mean_squared_error: 0.9802
# Epoch 2/10
# 1869/1875 [============================>.] - ETA: 0s - loss: 1.5512 - root_mean_squared_error: 1.2455INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.5489 - root_mean_squared_error: 1.2446 - val_loss: 0.5968 - val_root_mean_squared_error: 0.7726
# Epoch 3/10
# 1861/1875 [============================>.] - ETA: 0s - loss: 0.8164 - root_mean_squared_error: 0.9036INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.8160 - root_mean_squared_error: 0.9033 - val_loss: 0.5266 - val_root_mean_squared_error: 0.7257
# Epoch 4/10
# 1856/1875 [============================>.] - ETA: 0s - loss: 0.6927 - root_mean_squared_error: 0.8323INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.6920 - root_mean_squared_error: 0.8319 - val_loss: 0.5263 - val_root_mean_squared_error: 0.7254
# Epoch 5/10
# 1857/1875 [============================>.] - ETA: 0s - loss: 0.6616 - root_mean_squared_error: 0.8134INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6609 - root_mean_squared_error: 0.8130 - val_loss: 0.5042 - val_root_mean_squared_error: 0.7101
# Epoch 6/10
# 1865/1875 [============================>.] - ETA: 0s - loss: 0.6507 - root_mean_squared_error: 0.8067INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6505 - root_mean_squared_error: 0.8065 - val_loss: 0.5037 - val_root_mean_squared_error: 0.7097
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6453 - root_mean_squared_error: 0.8033 - val_loss: 0.5082 - val_root_mean_squared_error: 0.7128
# Epoch 8/10
# 1855/1875 [============================>.] - ETA: 0s - loss: 0.6396 - root_mean_squared_error: 0.7998INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.6411 - root_mean_squared_error: 0.8007 - val_loss: 0.4912 - val_root_mean_squared_error: 0.7009
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6398 - root_mean_squared_error: 0.7999 - val_loss: 0.4938 - val_root_mean_squared_error: 0.7027
# Epoch 10/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.6383 - root_mean_squared_error: 0.7989- ETA: 1s - loss: 0.6311 -INFO:tensorflow:Assets written to: model3\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6385 - root_mean_squared_error: 0.7991 - val_loss: 0.4894 - val_root_mean_squared_error: 0.6996

# %% [markdown]
# We will generate a forecast for 1 hour after the last timestamp in the dataset

# %%
X_=X_train1[60000-1]
X_ = X_.reshape(1, 5, 1)
Y_ = model3.predict(X_).reshape(-1, 1)
Y_
# Out:
# array([[16.513882]], dtype=float32)
